# %%
print("Starting computation...")
import math
import time

time.sleep(1)
print("Warming up...")

# %%
result = sum(math.sin(x) ** 2 for x in range(200000)) / 200000
print("Result:", result)

# %%
from pathlib import Path

output_dir = Path("outputs")
output_dir.mkdir(exist_ok=True)
(output_dir / "result.txt").write_text(str(result))
print("Wrote outputs/result.txt")
